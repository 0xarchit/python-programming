# %%
# ==, !=, >=, <=, >, <

# %%
a= 10
b= 12
out= a==b
print(out)
# Out:
# False

# %%
a= 12
b= 12
out= a==b
print(out)
# Out:
# True

# %%
a= 12.0
b= 12
out= a==b
print(out)
# Out:
# True

# %%
a= 10
b= 12
out= a!=b
print(out)
# Out:
# True

# %%
a= "hello"
b= "Hello"
out= a==b
print(out)
# Out:
# False
