# %%
# negative positive without comparision

n = -3
re = n >> 31
if re & 1:
    print("Negative number")
elif not n:
    print("Zero")
else:
    print("Positive number")
# Out:
# Negative number

# %%
'''
tuple initialization
'''
tup = (10,)
print(type(tup))
val = 2, 4, 5, 6
print(type(val))
# Out:
# <class 'tuple'>
# <class 'tuple'>
