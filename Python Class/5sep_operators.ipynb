# %%
a= 23
b= 23
c= a+b #a and b are operand and + is operator
print(c)
# Out:
# 46

# %%
a= 2
b= 4
c= a-(b+a)-b
print(c)
# Out:
# -8

# %%
a= 2
b= 4
c= a-b*a-b
print(c)
# Out:
# -10

# %%
a= 2
b= 4
c= a-b/a*b
print(c)
# Out:
# -6.0

# %%
a= 2
b= 4
c= a-b*a/b
print(c)
# Out:
# 0.0

# %%
a = eval(input("enter value for a: "))
b = eval(input("enter value for b: "))
c = int(input("enter 0 or 1: "))

print(a * c + b * (1 - c))
# Out:
# 21

# %%
#write a python program wether a number given is even or odd without if else

a=int(input("enter a number: "))
# b= a%2==0
out= 'even'*(a%2==0) + 'odd'*(a%2!=0)
print(out)
# Out:
# odd

# %%
out= 'can vote'*(1-c) + 'cant vote'*c

# %%
# write a python program to find floor value of a user entered real number.
a= float(input("enter a number: "))
print(int(a//1))
# Out:
# 3

# %%
# write a python program to find ceil value of a user entered real number.
a= float(input("enter a number: "))
out= -(-a//1)
print(out)
# Out:
# 4
