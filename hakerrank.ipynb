# %%
'''
Read an integer number in Decimal and converts it into Binary Number System.

The logic behind to implement this program -

Get remainder using modulus operator by 2 and store it into an array then divide number by 2, repeat this process till given number is greater than 0. Because 2 is the base of Binary Number System.

Input Format

Take an integer n from the user.
Constraints

n>=0
n<=100000
Output Format

Print the binary value of the entered number
'''
n = int(input("Enter a number: "))
binary = ""
while n > 0:
    remainder = n % 2
    binary = str(remainder) + binary
    n = n // 2
print("Binary representation:", binary)
# Out:
# Binary representation: 110

# %%
'''
You are organizing a fundraising event, and you want to distribute donation amounts based on specific criteria. You decide to sum up all the natural numbers up to a given integer ( N ). This sum will represent the total target donation for each participant.

Given an integer ( N ), your task is to calculate the sum of all natural numbers from 1 to ( N ). If ( N ) is less than 1, the sum should be 0, as there are no natural numbers to sum in that case.

For example: - For ( N = 5 ), the sum of natural numbers would be ( 1 + 2 + 3 + 4 + 5 = 15 ). - For ( N = 10 ), the sum would be ( 1 + 2 + 3 + ... + 10 = 55 ).

Write a function that takes a single integer ( N ) as input and returns the sum of all natural numbers up to ( N ).

Problem Statement:
Given an integer ( N ), compute the sum of all natural numbers from 1 to ( N ). If ( N ) is less than 1, the display 0.
'''
N = int(input("Enter a number: "))
if N < 1:
    print(0)
else:
    sum = 0
    for i in range(1, N + 1):
        sum += i
    print(sum)
# Out:
# 15

# %%
'''
Write a program for given three integers a, b, and x, display a if x is 1 and b if x is 0, using only mathematical or bitwise operations. Assume x can only be 1 or 0.

Note: flow control statements not allowed (if-else and loops not allowed)

Input Format

three integers in separate lines

1. first integer value of a
2. second integer value of b
3. third integer value of x

Constraints

None

Output Format

diplay value of integer a or integer b

Sample Input 0

2016
2560
0

Sample Output 0

2560

Explanation 0

here the value of x is 0 diplay value of b is 2560

Sample Input 1

1024
784
1

Sample Output 1

1024


'''

a = int(input('enter a: '))
b = int(input('enter b: '))
x = int(input('enter x: '))
print(a * x + b * (1 - x))
# Out:
# 1024

# %%
'''
Harry got a letter from Hogwarts School to join the wizardry. This letter consists of a magical key (6174) and a 4-digit number n with at least two distinct digits. Harry has to count in how many steps this number n can be converted to magical key invented by professor Dumbledore with this procedure as follows:

1.For number n, create two new numbers x and y consists of the digits in n in ascending and descending order respectively.
2.Subtract the smaller number from the larger number.
Help harry to count the steps to enter in the school.


'''

'''
example:

    N = 1234
    Step 1: x = 4321 y= 1234 => n = x-y => 3087
    Step 2: x = 8730 y= 0378 => n = x-y => 8352
    Step 3: x = 8532 y= 2358 => n = x-y => 6174
    you are done.
    Answer is 3

    Sample Input 0

1235

Sample Output 0

7



'''
steps = 0
n = int(input())
while n != 6174 and n != 0:
    if n < 1000:
        n = int(str(n) + '0')
    digits = sorted(str(n), reverse=True)
    x = int(''.join(digits))
    y = int(''.join(sorted(str(n))))
    if x == y:
        n = int(str(n) + '0')
        continue
    n = x - y
    steps += 1
print(steps)
